# %%
import pandas as pd
import requests 
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
#Website 2: An article about federal and state policy around gender-affirming care for minors
url = 'https://www.kff.org/other/issue-brief/youth-access-to-gender-affirming-care-the-federal-and-state-policy-landscape/'

r = requests.get(url) 
  
# check status code for response received 
# success code - 200 
print(r) 
  
# print content of request 

#print(r.text)
# Out:
# <Response [200]>

# %%
type(r.text)
#html_string = r.content
# Out:
# str

# %%
tree = BeautifulSoup(r.text)
good_html = tree.prettify()
#tree
#good_html

# %%
html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")

# kill all script and style elements
for script in soup(["script", "style"]):
    script.extract()    # rip it out

#soup
# get text
text = soup.get_text()
print(type(text))
# Out:
# <class 'str'>

# %%
#cleaning text
# break into lines and remove leading and trailing space on each
lines = (line.strip() for line in text.splitlines())
#print(text)
#print(lines)

# %%
# break multi-headlines into a line each
chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
#print(chunks)

# %%
# drop blank lines
text = '\n'.join(chunk for chunk in chunks if chunk)
#textdf = pd.DataFrame(text)
#print(textdf)
#print(type(text))
print(text)
# Out:
# Youth Access to Gender Affirming Care: The Federal and State Policy Landscape | KFF
# Home
# Topics
# Affordable Care Act
# COVID-19
# Global Health Policy
# Health Costs
# HIV/AIDS
# Medicaid
# Medicare
# Mental Health
# Patient and Consumer Protections
# Private Insurance
# Racial Equity and Health Policy
# Uninsured
# Women’s Health Policy
# Polling
# State Health Facts
# State Health Facts
# Custom State Reports
# Graphics & Interactives
# Charts & Slides
# KFF Health News
# Social Impact Media
# Peterson-KFF Health System Tracker
# Newsroom
# Newsroom
# News Releases
# Events
# Subscribe to Emails
# Cite Us/Reprint
# Media Contacts
# Join Our Team
# About Us
# About KFF
# From Drew Altman
# Our People
# Our Programs
# KFF Board
# Contact Us
# Support Our Work
# The independent source for health policy research, polling, and news.
# menu
# The independent source for health policy research, polling, and news.
# Donate
# Open Search...
# Search KFF.org
# Follow us
# Email
# ...

# %%
file2 = open('web2text.txt', 'w')
file2.close()

with open('web2text.txt', 'w') as f:
    f.writelines(text)

# Using readlines()
file2 = open('web2text.txt', 'r')
Lines = file2.readlines()
#print(len(Lines))

count = 0
# Strips the newline character
for line in Lines:
    print("Line{}: {}".format(count, line.strip()))
    count += 1
    #print(line.strip())
# Out:
# Line0: Youth Access to Gender Affirming Care: The Federal and State Policy Landscape | KFF
# Line1: Home
# Line2: Topics
# Line3: Affordable Care Act
# Line4: COVID-19
# Line5: Global Health Policy
# Line6: Health Costs
# Line7: HIV/AIDS
# Line8: Medicaid
# Line9: Medicare
# Line10: Mental Health
# Line11: Patient and Consumer Protections
# Line12: Private Insurance
# Line13: Racial Equity and Health Policy
# Line14: Uninsured
# Line15: Women’s Health Policy
# Line16: Polling
# Line17: State Health Facts
# Line18: State Health Facts
# Line19: Custom State Reports
# Line20: Graphics & Interactives
# Line21: Charts & Slides
# Line22: KFF Health News
# Line23: Social Impact Media
# Line24: Peterson-KFF Health System Tracker
# Line25: Newsroom
# Line26: Newsroom
# Line27: News Releases
# Line28: Events
# Line29: Subscribe to Emails
# Line30: Cite Us/Reprint
# Line31: Media Contacts
# Line32: Join Our Team
# Line33: About Us
# Line34: About KFF
# Line35: From Drew Altman
# ...

# %%
f = open('web2text.txt', 'r')

lista = f.readlines()
listb = lista[[62],65,67,69]
listc = lista[71:113]

#lista.reverse()
for i in listb:
    print(i)
for i in listc:
    print(i)
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 4
#       1 f = open('web2text.txt', 'r')
#       3 lista = f.readlines()
# ----> 4 listb = lista[[62,65,67,69]]
#       5 listc = lista[71:113]
#       7 #lista.reverse()
#
# TypeError: list indices must be integers or slices, not list

# %%
# writing to file
file2 = open('web2text_isolated.txt', 'w')
file2.writelines(listb)
file2.writelines(listc)
file2.close()
