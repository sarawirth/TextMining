# %%
#newsapi.ai key: d9052625-a43b-4f63-b861-c1c8abe115bc
#newsAPI key: c3645cc0bc8044bb97ddf2951e63c9fd
#!pip install requests_html

# %% [markdown]
# NewsAPI HTTP Status Codes
# 200	Success. Everything worked as expected.
# 204	Information not available. Request succeeded, but the requested information is not available.
# 400	Bad request. The request was unacceptable, most likely due to invalid or missing parameter.
# 401	User's limit reached. The user reached the limit of the tokens in his account. The requests are rejected.
# 403	Forbidden. The user's IP or account is disabled, or if all the tokens have been used. Check the error message for more details.
# 500	Internal error. Internal error occured while processing the request.
# 503	Service unavailable. The service is currently not available.

# %%
import requests  #to query the API 
import re  #regular expressions
import pandas as pd   # for dataframes
import json

import sklearn
from sklearn.feature_extraction.text import CountVectorizer  
 
#for text vectorization
#print(sklearn.__version__)

#from requests_html import HTMLSession
#from requests_html import AsyncHTMLSession

# %% [markdown]
# source": {
# "id": "the-washington-post",
# "name": "The Washington Post"
# }
#
# source": {
# "id": "cbs-news",
# "name": "CBS News"
#
# "source": {
# "id": "espn",
# "name": "ESPN"
#
# "source": {
# "id": "associated-press",
# "name": "Associated Press"
#
# -"source": {
# "id": "cnn",
# "name": "CNN"
#
# "source": {
# "id": null,
# "name": "BBC News"
#
# source": {
# "id": "fox-news",
# "name": "Fox News"
#
#     "source": {
# "id": "abc-news",
# "name": "ABC News"

# %%
## Create a new csv file to save the headlines
filename='TopicQuery_jsontxt.csv'

# %%
MyFILE=open(filename,"w")
### Place the column names in - write to the first row
WriteThis="Topic,Headline\n"
MyFILE.write(WriteThis)
MyFILE.close()

# %%
#erases file content if you need to overwrite during troubleshooting
MyFILE=open(filename,"r+")
MyFILE.truncate(0)
# Out:
# 0

# %%
url = ('https://newsapi.org/v2/everything?'
       'q=(transgender)AND(rights)&'
        'page=1&'
       #'from=2021-02-06&' 
       #'to=2020-03-07&'
       #'pageSize=100&'
       #'language=en&'
       #'sources=cbs-news,cnn,fox-news,abc-news,the-washington-post&'
       'apiKey=c3645cc0bc8044bb97ddf2951e63c9fd'
)
url2 = ('https://newsapi.org/v2/everything?'
       'q=(transgender)AND(rights)&'
        'page=2&'
       #'from=2021-02-06&' 
       #'to=2020-03-07&'
       #'pageSize=100&'
       #'language=en&'
       #'sources=cbs-news,cnn,fox-news,abc-news,the-washington-post&'
       'apiKey=c3645cc0bc8044bb97ddf2951e63c9fd'
)
url3 = ('https://newsapi.org/v2/everything?'
       'q=(transgender)AND(policy)&'
        'page=1&'
       #'from=2021-02-06&' 
       #'to=2020-03-07&'
       #'pageSize=100&'
       #'language=en&'
       #'sources=cbs-news,cnn,fox-news,abc-news,the-washington-post&'
       'apiKey=c3645cc0bc8044bb97ddf2951e63c9fd'
)
url4 = ('https://newsapi.org/v2/everything?'
       'q=(transgender)AND(policy)&'
        'page=2&'
       #'from=2021-02-06&' 
       #'to=2020-03-07&'
       #'pageSize=100&'
       #'language=en&'
       #'sources=cbs-news,cnn,fox-news,abc-news,the-washington-post&'
       'apiKey=c3645cc0bc8044bb97ddf2951e63c9fd'
)
url5 = ('https://newsapi.org/v2/everything?'
       'q=(transgender)AND(surgery)&'
        'page=1&'
       #'from=2021-02-06&' 
       #'to=2020-03-07&'
       #'pageSize=100&'
       #'language=en&'
       #'sources=cbs-news,cnn,fox-news,abc-news,the-washington-post&'
       'apiKey=c3645cc0bc8044bb97ddf2951e63c9fd'
)
url6 = ('https://newsapi.org/v2/everything?'
       'q=(transgender)AND(surgery)&'
        'page=2&'
       #'from=2021-02-06&' 
       #'to=2020-03-07&'
       #'pageSize=100&'
       #'language=en&'
       #'sources=cbs-news,cnn,fox-news,abc-news,the-washington-post&'
       'apiKey=c3645cc0bc8044bb97ddf2951e63c9fd'
)

# %%
r = requests.get(url)
print(r)

jsontxt = r.json()
#print(jsontxt2)
# Out:
# <Response [200]>

# %%
r2 = requests.get(url2)
print(r2)

jsontxt2 = r2.json()
#print(jsontxt2)
# Out:
# <Response [200]>

# %%
r3 = requests.get(url3)
print(r)

jsontxt3 = r3.json()
#print(jsontxt2)
# Out:
# <Response [200]>

# %%
r4 = requests.get(url4)
print(r4)

jsontxt4 = r4.json()
#print(jsontxt2)
# Out:
# <Response [200]>

# %%
r5 = requests.get(url5)
print(r5)

jsontxt5 = r5.json()
#print(jsontxt2)
# Out:
# <Response [200]>

# %%
r6 = requests.get(url6)
print(r6)

jsontxt6 = r6.json()
#print(jsontxt2)
# Out:
# <Response [200]>

# %%
for items in jsontxt['articles']:
    print(items)
    break
print(len(jsontxt['articles']))
# Out:
# {'source': {'id': None, 'name': 'NPR'}, 'author': 'Regan McCarthy', 'title': 'A Florida activist creates safe spaces as laws and rhetoric turn against trans rights', 'description': 'In founding Capital Tea, Janel Diaz sought to provide the kind of services that she had needed after her transition.', 'url': 'https://www.npr.org/2024/03/31/1241386011/florida-trans-rights-activist-book-ban-rupaul', 'urlToImage': 'https://media.npr.org/assets/img/2024/03/29/image001_wide-0a0af77c77bc9c2a4133f345b06566b19f5ef857-s1400-c100.jpg', 'publishedAt': '2024-03-31T11:00:57Z', 'content': "Advocates outside Florida's historic Capitol wave drag pride flags during the Drag Queens March in 2023.\r\nErich Martin\r\nOn International Transgender Visibility Day, we take a look someone offering sa… [+8179 chars]"}
# 100

# %%
print(len(jsontxt2['articles']))
print(len(jsontxt3['articles']))
print(len(jsontxt4['articles']))
print(len(jsontxt5['articles']))
print(len(jsontxt6['articles']))
# Out:
# 100
# 100
# 100
# 100
# 100

# %%
## Open the file for append
MyFILE=open(filename, "a")
for items in jsontxt['articles']:
    topic = "rights"
    
    Headline=items["description"]
    if Headline == "[Removed]":
        Headline = "None"
    Headline=re.sub(r'[,.;@#?!&$\-\']+', ' ', Headline, flags=re.IGNORECASE)
    Headline=re.sub(' +', ' ', Headline, flags=re.IGNORECASE)
    Headline=re.sub(r'\"', ' ', Headline, flags=re.IGNORECASE)
    Headline=re.sub(r'[^a-zA-Z]', " ", Headline, flags=re.VERBOSE)
    ## Be sure there are no commas in the headlines or it will
    ## write poorly to a csv file....
    Headline=Headline.replace(',', '')
    Headline=' '.join(Headline.split())
    Headline=re.sub("\n|\r", "", Headline)
    
    ### AS AN OPTION - remove words of a given length............
    Headline = ' '.join([wd for wd in Headline.split() if (len(wd)>3 & len(wd)<14)])

    #print("Author: ", Author, "\n")
    #print("Title: ", Title, "\n")
    #print("Headline News Item: ", Headline, "\n\n")
    
    WriteThis=str(topic)+","+str(Headline).lower() + "\n"
    
    MyFILE.write(WriteThis)
    
## CLOSE THE FILE
MyFILE.close()

# %%
MyFILE=open(filename, "a")
for items in jsontxt2['articles']:
    topic = "rights"
    
    Headline=items["description"]
    if Headline == "[Removed]":
        Headline = "None"
    Headline=re.sub(r'[,.;@#?!&$\-\']+', ' ', Headline, flags=re.IGNORECASE)
    Headline=re.sub(' +', ' ', Headline, flags=re.IGNORECASE)
    Headline=re.sub(r'\"', ' ', Headline, flags=re.IGNORECASE)
    Headline=re.sub(r'[^a-zA-Z]', " ", Headline, flags=re.VERBOSE)
    ## Be sure there are no commas in the headlines or it will
    ## write poorly to a csv file....
    Headline=Headline.replace(',', '')
    Headline=' '.join(Headline.split())
    Headline=re.sub("\n|\r", "", Headline)
    
    ### AS AN OPTION - remove words of a given length............
    Headline = ' '.join([wd for wd in Headline.split() if (len(wd)>3 & len(wd)<14)])

    #print("Author: ", Author, "\n")
    #print("Title: ", Title, "\n")
    #print("Headline News Item: ", Headline, "\n\n")
    
    WriteThis=str(topic)+","+str(Headline).lower() + "\n"
    
    MyFILE.write(WriteThis)
    
## CLOSE THE FILE
MyFILE.close()

# %%
for items in jsontxt3['articles']:
    Headline=items["description"]
    print(type(Headline))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'NoneType'>
# <class 'NoneType'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
MyFILE=open(filename, "a")

for items in jsontxt3['articles']:
    topic = "policy"
    
    Headline=items["description"]
    
    
    #print(type(Headline))
    if Headline == "[Removed]":
        Headline = str("None")
        #print("removed")
    elif type(Headline) == type(None):
        Headline == str("None")
        #print("type",Headline)
    elif Headline == None:
        Headline == str("None")
        #print("nnnone",Headline)
        
    #print(Headline)
    #print(type(Headline))
    if Headline != None:
        
        Headline=re.sub(r'[,.;@#?!&$\-\']+', ' ', Headline, flags=re.IGNORECASE)
        Headline=re.sub(' +', ' ', Headline, flags=re.IGNORECASE)
        Headline=re.sub(r'\"', ' ', Headline, flags=re.IGNORECASE)
        Headline=re.sub(r'[^a-zA-Z]', " ", Headline, flags=re.VERBOSE)
    ## Be sure there are no commas in the headlines or it will
    ## write poorly to a csv file....
        Headline=Headline.replace(',', '')
        Headline=' '.join(Headline.split())
        Headline=re.sub("\n|\r", "", Headline)
    
    ### AS AN OPTION - remove words of a given length............
        Headline = ' '.join([wd for wd in Headline.split() if (len(wd)>3 & len(wd)<14)])

    #print("Author: ", Author, "\n")
    #print("Title: ", Title, "\n")
    #print("Headline News Item: ", Headline, "\n\n")
    
    WriteThis=str(topic)+","+str(Headline).lower() + "\n"
    #print(i,WriteThis)
    MyFILE.write(WriteThis)
    
    
## CLOSE THE FILE
MyFILE.close()

# %%
MyFILE=open(filename, "a")

for items in jsontxt4['articles']:
    topic = "policy"
    
    Headline=items["description"]
    
    
    #print(type(Headline))
    if Headline == "[Removed]":
        Headline = str("None")
        #print("removed")
    elif type(Headline) == type(None):
        Headline == str("None")
        #print("type",Headline)
    elif Headline == None:
        Headline == str("None")
        #print("nnnone",Headline)
        
    #print(Headline)
    #print(type(Headline))
    if Headline != None:
        
        Headline=re.sub(r'[,.;@#?!&$\-\']+', ' ', Headline, flags=re.IGNORECASE)
        Headline=re.sub(' +', ' ', Headline, flags=re.IGNORECASE)
        Headline=re.sub(r'\"', ' ', Headline, flags=re.IGNORECASE)
        Headline=re.sub(r'[^a-zA-Z]', " ", Headline, flags=re.VERBOSE)
    ## Be sure there are no commas in the headlines or it will
    ## write poorly to a csv file....
        Headline=Headline.replace(',', '')
        Headline=' '.join(Headline.split())
        Headline=re.sub("\n|\r", "", Headline)
    
    ### AS AN OPTION - remove words of a given length............
        Headline = ' '.join([wd for wd in Headline.split() if (len(wd)>3 & len(wd)<14)])

    #print("Author: ", Author, "\n")
    #print("Title: ", Title, "\n")
    #print("Headline News Item: ", Headline, "\n\n")
    
    WriteThis=str(topic)+","+str(Headline).lower() + "\n"
    #print(i,WriteThis)
    MyFILE.write(WriteThis)
    
    
## CLOSE THE FILE
MyFILE.close()

# %%
MyFILE=open(filename, "a")

for items in jsontxt5['articles']:
    topic = "surgery"
    
    Headline=items["description"]
    
    
    #print(type(Headline))
    if Headline == "[Removed]":
        Headline = str("None")
        #print("removed")
    elif type(Headline) == type(None):
        Headline == str("None")
        #print("type",Headline)
    elif Headline == None:
        Headline == str("None")
        #print("nnnone",Headline)
        
    #print(Headline)
    #print(type(Headline))
    if Headline != None:
        
        Headline=re.sub(r'[,.;@#?!&$\-\']+', ' ', Headline, flags=re.IGNORECASE)
        Headline=re.sub(' +', ' ', Headline, flags=re.IGNORECASE)
        Headline=re.sub(r'\"', ' ', Headline, flags=re.IGNORECASE)
        Headline=re.sub(r'[^a-zA-Z]', " ", Headline, flags=re.VERBOSE)
    ## Be sure there are no commas in the headlines or it will
    ## write poorly to a csv file....
        Headline=Headline.replace(',', '')
        Headline=' '.join(Headline.split())
        Headline=re.sub("\n|\r", "", Headline)
    
    ### AS AN OPTION - remove words of a given length............
        Headline = ' '.join([wd for wd in Headline.split() if (len(wd)>3 & len(wd)<14)])

    #print("Author: ", Author, "\n")
    #print("Title: ", Title, "\n")
    #print("Headline News Item: ", Headline, "\n\n")
    
    WriteThis=str(topic)+","+str(Headline).lower() + "\n"
    #print(i,WriteThis)
    MyFILE.write(WriteThis)
    
    
## CLOSE THE FILE
MyFILE.close()

# %%
MyFILE=open(filename, "a")

for items in jsontxt6['articles']:
    topic = "surgery"
    
    Headline=items["description"]
    
    
    #print(type(Headline))
    if Headline == "[Removed]":
        Headline = str("None")
        #print("removed")
    elif type(Headline) == type(None):
        Headline == str("None")
        #print("type",Headline)
    elif Headline == None:
        Headline == str("None")
        #print("nnnone",Headline)
        
    #print(Headline)
    #print(type(Headline))
    if Headline != None:
        
        Headline=re.sub(r'[,.;@#?!&$\-\']+', ' ', Headline, flags=re.IGNORECASE)
        Headline=re.sub(' +', ' ', Headline, flags=re.IGNORECASE)
        Headline=re.sub(r'\"', ' ', Headline, flags=re.IGNORECASE)
        Headline=re.sub(r'[^a-zA-Z]', " ", Headline, flags=re.VERBOSE)
    ## Be sure there are no commas in the headlines or it will
    ## write poorly to a csv file....
        Headline=Headline.replace(',', '')
        Headline=' '.join(Headline.split())
        Headline=re.sub("\n|\r", "", Headline)
    
    ### AS AN OPTION - remove words of a given length............
        Headline = ' '.join([wd for wd in Headline.split() if (len(wd)>3 & len(wd)<14)])

    #print("Author: ", Author, "\n")
    #print("Title: ", Title, "\n")
    #print("Headline News Item: ", Headline, "\n\n")
    
    WriteThis=str(topic)+","+str(Headline).lower() + "\n"
    #print(i,WriteThis)
    MyFILE.write(WriteThis)
    
    
## CLOSE THE FILE
MyFILE.close()

# %%
## Read to DF
newsAPI_df=pd.read_csv(filename, on_bad_lines = 'warn').dropna()

# %%
len(newsAPI_df)
newsAPI_df=newsAPI_df.loc[newsAPI_df["Headline"] != "none"]
len(newsAPI_df)
# Out:
# 564

# %%
newsAPI_df.head()
# Out:
#     Topic                                           Headline
# 0  rights  founding capital janel diaz sought provide kin...
# 1  rights  former kentucky swimmer riley gaines among mor...
# 2  rights  thailand lower house passed bill giving legal ...
# 3  rights  benedict attacked their oklahoma high school f...
# 4  rights  people have been charged death transgender act...

# %%
newsAPI_df.to_csv('HeadlineTopics_DT.csv')

# %%
# !pip install WordCloud
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import csv
import re
# Out:
# Collecting WordCloud
#   Using cached wordcloud-1.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from WordCloud) (3.6.2)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from WordCloud) (9.2.0)
# Requirement already satisfied: numpy>=1.6.1 in /opt/conda/lib/python3.10/site-packages (from WordCloud) (1.23.5)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->WordCloud) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->WordCloud) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->WordCloud) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->WordCloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->WordCloud) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->WordCloud) (22.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->WordCloud) (4.38.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->WordCloud) (1.16.0)
# Installing collected packages: WordCloud
# Successfully installed WordCloud-1.9.3

# %%
text1 = newsAPI_df['Headline'].to_string(index=False).lower()
text1 = text1.replace('\n', " ")

# %%
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text1)

# %%
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()
